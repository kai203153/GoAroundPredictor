# %%
import pandas as pd
import numpy as np

# Load the CSV file
df = pd.read_csv('data/sfo_goarounds.csv', low_memory=False)

# Filter to only rows where has_ga is True
df_goarounds = df[df['has_ga'] == True]

# Sort by time column in descending order (newest first)
df_goarounds = df_goarounds.sort_values('time', ascending=False)

# View the first few rows
df_goarounds.head(1021)
# Out:
#                              time  icao24 callsign airport runway  has_ga  \
# 197056  2019-12-30 15:29:33+00:00  a0a80e  SKW5976    KSFO    28L    True
# 196906  2019-12-30 05:12:47+00:00  a9d59f  UAL2366    KSFO    28R    True
# 196803  2019-12-30 02:13:24+00:00  aa5690   UAL736    KSFO    28L    True
# 196770  2019-12-30 01:15:09+00:00  ad6539  SKW5657    KSFO    28L    True
# 196752  2019-12-30 00:51:16+00:00  a0e5d7  SKW5812    KSFO    28R    True
# ...                           ...     ...      ...     ...    ...     ...
# 545     2019-01-02 05:26:44+00:00  aacd50   UAL683    KSFO    28R    True
# 508     2019-01-02 04:11:58+00:00  a4460d  UAL2201    KSFO    28L    True
# 477     2019-01-02 03:16:28+00:00  a57796   UAL737    KSFO    28R    True
# 202     2019-01-01 16:45:33+00:00  a047db  SKW5694    KSFO    28R    True
# 85      2019-01-01 04:58:50+00:00  aaa5d4  UAL1152    KSFO    28L    True
#
#         n_approaches  n_rwy_approached registration typecode  ...  \
# ...
